# %% [markdown]
# # Download all of the announcements

# %% [markdown]
# ## 1. FOMC Statement Download

# %%
import os
import requests
import pandas as pd
from datetime import datetime

download_folder = "raw_data/announcements"
if not os.path.exists(download_folder):
    os.makedirs(download_folder)

def download_pdf(url, date_str):
    try:
        response = requests.get(url)
        response.raise_for_status()
        filename = f"monetary{date_str}a1.pdf"
        filepath = os.path.join(download_folder, filename)
        with open(filepath, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded PDF for {date_str}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download {url}: {e}")

def download_html(url, date_str):
    try:
        response = requests.get(url)
        response.raise_for_status()
        filename = f"monetary{date_str}a.html"
        filepath = os.path.join(download_folder, filename)
        with open(filepath, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded HTML for {date_str}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download {url}: {e}")

def convert_date_format(date_str):
    try:
        date_obj = datetime.strptime(date_str, "%m/%d/%y")
        return date_obj.strftime("%Y%m%d")
    except ValueError as e:
        print(f"Skipping invalid date: {date_str}")
        return None

csv_file_path = 'dates/fomc_statements.csv'  
df = pd.read_csv(csv_file_path)

for index, row in df.iterrows():
    original_date = row['Date']
    date_str = convert_date_format(original_date)
    
    if date_str:
        year = date_str[:4]
        month = int(date_str[4:6])
        day = int(date_str[6:8])
        
        if int(year) < 2002 or (int(year) == 2002 and month < 3) or (int(year) == 2002 and month == 3 and day <= 19):
            html_url = f"https://www.federalreserve.gov/boarddocs/press/general/{year}/{date_str}/"
        elif int(year) < 2006:
            html_url = f"https://www.federalreserve.gov/boarddocs/press/monetary/{year}/{date_str}/default.htm"
        else:
            html_url = f"https://www.federalreserve.gov/newsevents/pressreleases/monetary{date_str}a.htm"
        
        pdf_url = f"https://www.federalreserve.gov/monetarypolicy/files/monetary{date_str}a1.pdf"
        
    
        # download_pdf(pdf_url, date_str)  
        download_html(html_url, date_str)
# Out:
# Downloaded HTML for 20000202
# Downloaded HTML for 20000321
# Downloaded HTML for 20000516
# Downloaded HTML for 20000628
# Downloaded HTML for 20000822
# Downloaded HTML for 20001003
# Downloaded HTML for 20001115
# Downloaded HTML for 20001219
# Downloaded HTML for 20010131
# Downloaded HTML for 20010320
# Downloaded HTML for 20010515
# Downloaded HTML for 20010627
# Downloaded HTML for 20010821
# Downloaded HTML for 20011002
# Downloaded HTML for 20011106
# Downloaded HTML for 20011211
# Downloaded HTML for 20020130
# Downloaded HTML for 20020319
# Downloaded HTML for 20020507
# Downloaded HTML for 20020626
# Downloaded HTML for 20020813
# Downloaded HTML for 20020924
# Downloaded HTML for 20021106
# Downloaded HTML for 20021210
# Downloaded HTML for 20030129
# Downloaded HTML for 20030318
# Downloaded HTML for 20030506
# Downloaded HTML for 20030625
# Downloaded HTML for 20030812
# Downloaded HTML for 20030916
# Downloaded HTML for 20031028
# Downloaded HTML for 20031209
# Downloaded HTML for 20040128
# Downloaded HTML for 20040316
# Downloaded HTML for 20040504
# Downloaded HTML for 20040630
# Downloaded HTML for 20040810
# Downloaded HTML for 20040921
# Downloaded HTML for 20041110
# Downloaded HTML for 20041214
# Downloaded HTML for 20050202
# Downloaded HTML for 20050322
# Downloaded HTML for 20050503
# Downloaded HTML for 20050630
# Downloaded HTML for 20050809
# Downloaded HTML for 20050920
# Downloaded HTML for 20051101
# Downloaded HTML for 20051213
# Downloaded HTML for 20060131
# Downloaded HTML for 20060328
# Downloaded HTML for 20060510
# Downloaded HTML for 20060629
# Downloaded HTML for 20060808
# Downloaded HTML for 20060920
# Downloaded HTML for 20061025
# Downloaded HTML for 20061212
# Downloaded HTML for 20070131
# Downloaded HTML for 20070321
# Downloaded HTML for 20070509
# Downloaded HTML for 20070618
# Downloaded HTML for 20070807
# Downloaded HTML for 20070918
# Downloaded HTML for 20071031
# Downloaded HTML for 20071211
# Downloaded HTML for 20080130
# Downloaded HTML for 20080318
# Downloaded HTML for 20080430
# Downloaded HTML for 20080625
# Downloaded HTML for 20080805
# Downloaded HTML for 20080916
# Downloaded HTML for 20081029
# Downloaded HTML for 20081216
# Downloaded HTML for 20090128
# Downloaded HTML for 20090318
# Downloaded HTML for 20090429
# Downloaded HTML for 20090624
# Downloaded HTML for 20090812
# Downloaded HTML for 20090923
# Downloaded HTML for 20091104
# Downloaded HTML for 20091216
# Downloaded HTML for 20100127
# Downloaded HTML for 20100316
# Downloaded HTML for 20100428
# Downloaded HTML for 20100623
# Downloaded HTML for 20100810
# Downloaded HTML for 20100921
# Downloaded HTML for 20101103
# Downloaded HTML for 20101214
# Downloaded HTML for 20110126
# Downloaded HTML for 20110315
# Downloaded HTML for 20110427
# Downloaded HTML for 20110622
# Downloaded HTML for 20110809
# Downloaded HTML for 20110921
# Downloaded HTML for 20111102
# Downloaded HTML for 20111213
# Downloaded HTML for 20120125
# Downloaded HTML for 20120313
# Downloaded HTML for 20120425
# Downloaded HTML for 20120620
# Downloaded HTML for 20120801
# Downloaded HTML for 20120913
# Downloaded HTML for 20121024
# Downloaded HTML for 20121212
# Downloaded HTML for 20130130
# Downloaded HTML for 20130320
# Downloaded HTML for 20130501
# Downloaded HTML for 20130619
# Downloaded HTML for 20130731
# Downloaded HTML for 20130918
# Downloaded HTML for 20131030
# Downloaded HTML for 20131218
# Downloaded HTML for 20140129
# Downloaded HTML for 20140319
# Downloaded HTML for 20140430
# Downloaded HTML for 20140618
# Downloaded HTML for 20140730
# Downloaded HTML for 20140917
# Downloaded HTML for 20141029
# Downloaded HTML for 20141217
# Downloaded HTML for 20150128
# Downloaded HTML for 20150318
# Downloaded HTML for 20150429
# Downloaded HTML for 20150617
# Downloaded HTML for 20150729
# Downloaded HTML for 20150917
# Downloaded HTML for 20151028
# Downloaded HTML for 20151216
# Downloaded HTML for 20160127
# Downloaded HTML for 20160316
# Downloaded HTML for 20160427
# Downloaded HTML for 20160615
# Downloaded HTML for 20160727
# Downloaded HTML for 20160921
# Downloaded HTML for 20161102
# Downloaded HTML for 20161214
# Downloaded HTML for 20170201
# Downloaded HTML for 20170315
# Downloaded HTML for 20170503
# Downloaded HTML for 20170614
# Downloaded HTML for 20170726
# Downloaded HTML for 20170920
# Downloaded HTML for 20171101
# Downloaded HTML for 20171213
# Downloaded HTML for 20180131
# Downloaded HTML for 20180321
# Downloaded HTML for 20180502
# Downloaded HTML for 20180613
# Downloaded HTML for 20180801
# Downloaded HTML for 20180926
# Downloaded HTML for 20181108
# Downloaded HTML for 20181219
# Downloaded HTML for 20190130
# Downloaded HTML for 20190320
# Downloaded HTML for 20190501
# Downloaded HTML for 20190619
# Downloaded HTML for 20190731
# Downloaded HTML for 20190918
# Downloaded HTML for 20191030
# Downloaded HTML for 20191211
# Downloaded HTML for 20200129
# Downloaded HTML for 20200303
# Downloaded HTML for 20200315
# Downloaded HTML for 20200323
# Downloaded HTML for 20200331
# Downloaded HTML for 20200429
# Downloaded HTML for 20200610
# Downloaded HTML for 20200729
# Downloaded HTML for 20200827
# Downloaded HTML for 20200916
# Downloaded HTML for 20201105
# Downloaded HTML for 20201216
# Downloaded HTML for 20210127
# Downloaded HTML for 20210317
# Downloaded HTML for 20210428
# Downloaded HTML for 20210616
# Downloaded HTML for 20210728
# Downloaded HTML for 20210922
# Downloaded HTML for 20211103
# Downloaded HTML for 20211215
# Downloaded HTML for 20220126
# Downloaded HTML for 20220316
# Downloaded HTML for 20220504
# Downloaded HTML for 20220615
# Downloaded HTML for 20220727
# Downloaded HTML for 20220921
# Downloaded HTML for 20221102
# Downloaded HTML for 20221214
# Downloaded HTML for 20230201
# Downloaded HTML for 20230322
# Downloaded HTML for 20230503
# Downloaded HTML for 20230614
# Downloaded HTML for 20230726
# Downloaded HTML for 20230920
# Downloaded HTML for 20231101
# Downloaded HTML for 20231213
# Downloaded HTML for 20240131
# Downloaded HTML for 20240320
# Downloaded HTML for 20240501
# Downloaded HTML for 20240612
# Downloaded HTML for 20240731
# Downloaded HTML for 20240918
# Downloaded HTML for 20241107
# Downloaded HTML for 20241218
# Downloaded HTML for 20250129
# Downloaded HTML for 20250319

# %% [markdown]
# ## 2. Intermeeting Transcripts download

# %%
import os
import requests
import pandas as pd
from datetime import datetime

download_folder = "raw_data/intermeeting"
if not os.path.exists(download_folder):
    os.makedirs(download_folder)

def download_minutes_html(url, date_str):
    try:
        response = requests.get(url)
        response.raise_for_status()
        filename = f"fomcminutes{date_str}.html"
        filepath = os.path.join(download_folder, filename)
        with open(filepath, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded intermeeting minutes HTML for {date_str}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download {url}: {e}")

def convert_date_format(date_str):
    try:
        date_obj = datetime.strptime(date_str, "%m/%d/%y")
        return date_obj.strftime("%Y%m%d"), date_obj
    except ValueError as e:
        print(f"Skipping invalid date: {date_str}")
        return None, None

# Read the CSV file
csv_file_path = 'dates/fomc_statements.csv'  
df = pd.read_csv(csv_file_path)

for index, row in df.iterrows():
    original_date = row['Date']  
    date_str, date_obj = convert_date_format(original_date)
    
    if date_str:
        cutoff_date = datetime(2007, 10, 30)

        if date_obj <= cutoff_date:
            minutes_url = f"https://www.federalreserve.gov/fomc/minutes/{date_str}.htm"
        else:
            minutes_url = f"https://www.federalreserve.gov/monetarypolicy/fomcminutes{date_str}.htm"
        
        download_minutes_html(minutes_url, date_str)
# Out:
# Downloaded intermeeting minutes HTML for 20000202
# Downloaded intermeeting minutes HTML for 20000321
# Downloaded intermeeting minutes HTML for 20000516
# Downloaded intermeeting minutes HTML for 20000628
# Downloaded intermeeting minutes HTML for 20000822
# Downloaded intermeeting minutes HTML for 20001003
# Downloaded intermeeting minutes HTML for 20001115
# Downloaded intermeeting minutes HTML for 20001219
# Downloaded intermeeting minutes HTML for 20010131
# Downloaded intermeeting minutes HTML for 20010320
# Downloaded intermeeting minutes HTML for 20010515
# Downloaded intermeeting minutes HTML for 20010627
# Downloaded intermeeting minutes HTML for 20010821
# Downloaded intermeeting minutes HTML for 20011002
# Downloaded intermeeting minutes HTML for 20011106
# Downloaded intermeeting minutes HTML for 20011211
# Downloaded intermeeting minutes HTML for 20020130
# Downloaded intermeeting minutes HTML for 20020319
# Downloaded intermeeting minutes HTML for 20020507
# Downloaded intermeeting minutes HTML for 20020626
# Downloaded intermeeting minutes HTML for 20020813
# Downloaded intermeeting minutes HTML for 20020924
# Downloaded intermeeting minutes HTML for 20021106
# Downloaded intermeeting minutes HTML for 20021210
# Downloaded intermeeting minutes HTML for 20030129
# Downloaded intermeeting minutes HTML for 20030318
# Downloaded intermeeting minutes HTML for 20030506
# Downloaded intermeeting minutes HTML for 20030625
# Downloaded intermeeting minutes HTML for 20030812
# Downloaded intermeeting minutes HTML for 20030916
# Downloaded intermeeting minutes HTML for 20031028
# Downloaded intermeeting minutes HTML for 20031209
# Downloaded intermeeting minutes HTML for 20040128
# Downloaded intermeeting minutes HTML for 20040316
# Downloaded intermeeting minutes HTML for 20040504
# Downloaded intermeeting minutes HTML for 20040630
# Downloaded intermeeting minutes HTML for 20040810
# Downloaded intermeeting minutes HTML for 20040921
# Downloaded intermeeting minutes HTML for 20041110
# Downloaded intermeeting minutes HTML for 20041214
# Downloaded intermeeting minutes HTML for 20050202
# Downloaded intermeeting minutes HTML for 20050322
# Downloaded intermeeting minutes HTML for 20050503
# Downloaded intermeeting minutes HTML for 20050630
# Downloaded intermeeting minutes HTML for 20050809
# Downloaded intermeeting minutes HTML for 20050920
# Downloaded intermeeting minutes HTML for 20051101
# Downloaded intermeeting minutes HTML for 20051213
# Downloaded intermeeting minutes HTML for 20060131
# Downloaded intermeeting minutes HTML for 20060328
# Downloaded intermeeting minutes HTML for 20060510
# Downloaded intermeeting minutes HTML for 20060629
# Downloaded intermeeting minutes HTML for 20060808
# Downloaded intermeeting minutes HTML for 20060920
# Downloaded intermeeting minutes HTML for 20061025
# Downloaded intermeeting minutes HTML for 20061212
# Downloaded intermeeting minutes HTML for 20070131
# Downloaded intermeeting minutes HTML for 20070321
# Downloaded intermeeting minutes HTML for 20070509
# Failed to download https://www.federalreserve.gov/fomc/minutes/20070618.htm: 404 Client Error: Not Found for url: https://www.federalreserve.gov/fomc/minutes/20070618.htm
# Downloaded intermeeting minutes HTML for 20070807
# Downloaded intermeeting minutes HTML for 20070918
# Downloaded intermeeting minutes HTML for 20071031
# Downloaded intermeeting minutes HTML for 20071211
# Downloaded intermeeting minutes HTML for 20080130
# Downloaded intermeeting minutes HTML for 20080318
# Downloaded intermeeting minutes HTML for 20080430
# Failed to download https://www.federalreserve.gov/monetarypolicy/fomcminutes20080625.htm: 404 Client Error: Not Found for url: https://www.federalreserve.gov/monetarypolicy/fomcminutes20080625.htm
# Downloaded intermeeting minutes HTML for 20080805
# Downloaded intermeeting minutes HTML for 20080916
# Downloaded intermeeting minutes HTML for 20081029
# Downloaded intermeeting minutes HTML for 20081216
# Downloaded intermeeting minutes HTML for 20090128
# Downloaded intermeeting minutes HTML for 20090318
# Downloaded intermeeting minutes HTML for 20090429
# Downloaded intermeeting minutes HTML for 20090624
# Downloaded intermeeting minutes HTML for 20090812
# Downloaded intermeeting minutes HTML for 20090923
# Downloaded intermeeting minutes HTML for 20091104
# Downloaded intermeeting minutes HTML for 20091216
# Downloaded intermeeting minutes HTML for 20100127
# Downloaded intermeeting minutes HTML for 20100316
# Downloaded intermeeting minutes HTML for 20100428
# Downloaded intermeeting minutes HTML for 20100623
# Downloaded intermeeting minutes HTML for 20100810
# Downloaded intermeeting minutes HTML for 20100921
# Downloaded intermeeting minutes HTML for 20101103
# Downloaded intermeeting minutes HTML for 20101214
# Downloaded intermeeting minutes HTML for 20110126
# Downloaded intermeeting minutes HTML for 20110315
# Downloaded intermeeting minutes HTML for 20110427
# Downloaded intermeeting minutes HTML for 20110622
# Downloaded intermeeting minutes HTML for 20110809
# Downloaded intermeeting minutes HTML for 20110921
# Downloaded intermeeting minutes HTML for 20111102
# Downloaded intermeeting minutes HTML for 20111213
# Downloaded intermeeting minutes HTML for 20120125
# Downloaded intermeeting minutes HTML for 20120313
# Downloaded intermeeting minutes HTML for 20120425
# Downloaded intermeeting minutes HTML for 20120620
# Downloaded intermeeting minutes HTML for 20120801
# Downloaded intermeeting minutes HTML for 20120913
# Downloaded intermeeting minutes HTML for 20121024
# Downloaded intermeeting minutes HTML for 20121212
# Downloaded intermeeting minutes HTML for 20130130
# Downloaded intermeeting minutes HTML for 20130320
# Downloaded intermeeting minutes HTML for 20130501
# Downloaded intermeeting minutes HTML for 20130619
# Downloaded intermeeting minutes HTML for 20130731
# Downloaded intermeeting minutes HTML for 20130918
# Downloaded intermeeting minutes HTML for 20131030
# Downloaded intermeeting minutes HTML for 20131218
# Downloaded intermeeting minutes HTML for 20140129
# Downloaded intermeeting minutes HTML for 20140319
# Downloaded intermeeting minutes HTML for 20140430
# Downloaded intermeeting minutes HTML for 20140618
# Downloaded intermeeting minutes HTML for 20140730
# Downloaded intermeeting minutes HTML for 20140917
# Downloaded intermeeting minutes HTML for 20141029
# Downloaded intermeeting minutes HTML for 20141217
# Downloaded intermeeting minutes HTML for 20150128
# Downloaded intermeeting minutes HTML for 20150318
# Downloaded intermeeting minutes HTML for 20150429
# Downloaded intermeeting minutes HTML for 20150617
# Downloaded intermeeting minutes HTML for 20150729
# Downloaded intermeeting minutes HTML for 20150917
# Downloaded intermeeting minutes HTML for 20151028
# Downloaded intermeeting minutes HTML for 20151216
# Downloaded intermeeting minutes HTML for 20160127
# Downloaded intermeeting minutes HTML for 20160316
# Downloaded intermeeting minutes HTML for 20160427
# Downloaded intermeeting minutes HTML for 20160615
# Downloaded intermeeting minutes HTML for 20160727
# Downloaded intermeeting minutes HTML for 20160921
# Downloaded intermeeting minutes HTML for 20161102
# Downloaded intermeeting minutes HTML for 20161214
# Downloaded intermeeting minutes HTML for 20170201
# Downloaded intermeeting minutes HTML for 20170315
# Downloaded intermeeting minutes HTML for 20170503
# Downloaded intermeeting minutes HTML for 20170614
# Downloaded intermeeting minutes HTML for 20170726
# Downloaded intermeeting minutes HTML for 20170920
# Downloaded intermeeting minutes HTML for 20171101
# Downloaded intermeeting minutes HTML for 20171213
# Downloaded intermeeting minutes HTML for 20180131
# Downloaded intermeeting minutes HTML for 20180321
# Downloaded intermeeting minutes HTML for 20180502
# Downloaded intermeeting minutes HTML for 20180613
# Downloaded intermeeting minutes HTML for 20180801
# Downloaded intermeeting minutes HTML for 20180926
# Downloaded intermeeting minutes HTML for 20181108
# Downloaded intermeeting minutes HTML for 20181219
# Downloaded intermeeting minutes HTML for 20190130
# Downloaded intermeeting minutes HTML for 20190320
# Downloaded intermeeting minutes HTML for 20190501
# Downloaded intermeeting minutes HTML for 20190619
# Downloaded intermeeting minutes HTML for 20190731
# Downloaded intermeeting minutes HTML for 20190918
# Downloaded intermeeting minutes HTML for 20191030
# Downloaded intermeeting minutes HTML for 20191211
# Downloaded intermeeting minutes HTML for 20200129
# Failed to download https://www.federalreserve.gov/monetarypolicy/fomcminutes20200303.htm: 404 Client Error: Not Found for url: https://www.federalreserve.gov/monetarypolicy/fomcminutes20200303.htm
# Downloaded intermeeting minutes HTML for 20200315
# Failed to download https://www.federalreserve.gov/monetarypolicy/fomcminutes20200323.htm: 404 Client Error: Not Found for url: https://www.federalreserve.gov/monetarypolicy/fomcminutes20200323.htm
# Failed to download https://www.federalreserve.gov/monetarypolicy/fomcminutes20200331.htm: 404 Client Error: Not Found for url: https://www.federalreserve.gov/monetarypolicy/fomcminutes20200331.htm
# Downloaded intermeeting minutes HTML for 20200429
# Downloaded intermeeting minutes HTML for 20200610
# Downloaded intermeeting minutes HTML for 20200729
# Failed to download https://www.federalreserve.gov/monetarypolicy/fomcminutes20200827.htm: 404 Client Error: Not Found for url: https://www.federalreserve.gov/monetarypolicy/fomcminutes20200827.htm
# Downloaded intermeeting minutes HTML for 20200916
# Downloaded intermeeting minutes HTML for 20201105
# Downloaded intermeeting minutes HTML for 20201216
# Downloaded intermeeting minutes HTML for 20210127
# Downloaded intermeeting minutes HTML for 20210317
# Downloaded intermeeting minutes HTML for 20210428
# Downloaded intermeeting minutes HTML for 20210616
# Downloaded intermeeting minutes HTML for 20210728
# Downloaded intermeeting minutes HTML for 20210922
# Downloaded intermeeting minutes HTML for 20211103
# Downloaded intermeeting minutes HTML for 20211215
# Downloaded intermeeting minutes HTML for 20220126
# Downloaded intermeeting minutes HTML for 20220316
# Downloaded intermeeting minutes HTML for 20220504
# Downloaded intermeeting minutes HTML for 20220615
# Downloaded intermeeting minutes HTML for 20220727
# Downloaded intermeeting minutes HTML for 20220921
# Downloaded intermeeting minutes HTML for 20221102
# Downloaded intermeeting minutes HTML for 20221214
# Downloaded intermeeting minutes HTML for 20230201
# Downloaded intermeeting minutes HTML for 20230322
# Downloaded intermeeting minutes HTML for 20230503
# Downloaded intermeeting minutes HTML for 20230614
# Downloaded intermeeting minutes HTML for 20230726
# Downloaded intermeeting minutes HTML for 20230920
# Downloaded intermeeting minutes HTML for 20231101
# Downloaded intermeeting minutes HTML for 20231213
# Downloaded intermeeting minutes HTML for 20240131
# Downloaded intermeeting minutes HTML for 20240320
# Downloaded intermeeting minutes HTML for 20240501
# Downloaded intermeeting minutes HTML for 20240612
# Downloaded intermeeting minutes HTML for 20240731
# Downloaded intermeeting minutes HTML for 20240918
# Downloaded intermeeting minutes HTML for 20241107
# Downloaded intermeeting minutes HTML for 20241218
# Downloaded intermeeting minutes HTML for 20250129
# Downloaded intermeeting minutes HTML for 20250319
